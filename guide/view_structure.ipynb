# %%
import seedir as sd

# %%
sd.seedir('C:\\Users\\nader\\DS_PROJECT', style='emoji')
# Out:
# 📁 DS_PROJECT/
# ├─📁 .dvc/
# │ ├─📄 .gitignore
# │ ├─📄 config
# │ ├─📁 plots/
# │ │ ├─📄 confusion.json
# │ │ ├─📄 confusion_normalized.json
# │ │ ├─📄 default.json
# │ │ ├─📄 linear.json
# │ │ ├─📄 scatter.json
# │ │ └─📄 smooth.json
# │ └─📁 tmp/
# │   ├─📄 lock
# │   ├─📄 rwlock
# │   ├─📄 state
# │   └─📄 updater.lock
# ├─📄 .dvcignore
# ├─📁 .git/
# │ ├─📄 COMMIT_EDITMSG
# │ ├─📄 config
# │ ├─📄 description
# │ ├─📄 HEAD
# │ ├─📁 hooks/
# │ │ ├─📄 applypatch-msg.sample
# │ │ ├─📄 commit-msg.sample
# │ │ ├─📄 fsmonitor-watchman.sample
# │ │ ├─📄 post-update.sample
# │ │ ├─📄 pre-applypatch.sample
# │ │ ├─📄 pre-commit.sample
# │ │ ├─📄 pre-merge-commit.sample
# │ │ ├─📄 pre-push.sample
# │ │ ├─📄 pre-rebase.sample
# │ │ ├─📄 pre-receive.sample
# │ │ ├─📄 prepare-commit-msg.sample
# │ │ ├─📄 push-to-checkout.sample
# │ │ └─📄 update.sample
# │ ├─📄 index
# │ ├─📁 info/
# │ │ └─📄 exclude
# │ ├─📁 logs/
# │ │ ├─📄 HEAD
# │ │ └─📁 refs/
# │ │   └─📁 heads/
# │ │     └─📄 master
# │ ├─📁 objects/
# │ │ ├─📁 00/
# ...

# %% [markdown]
# ---
